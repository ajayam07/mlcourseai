# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course
#
# Author: [Yury Kashnitsky](https://yorko.github.io). Translated and edited by [Christina Butsko](https://www.linkedin.com/in/christinabutsko/), [Nerses Bagiyan](https://www.linkedin.com/in/nersesbagiyan/), [Yulia Klimushina](https://www.linkedin.com/in/yuliya-klimushina-7168a9139), and [Yuanyuan Pao](https://www.linkedin.com/in/yuanyuanpao/). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# # <center>Topic 4. Linear Classification and Regression
# ## <center> Part 3. An Illustrative Example of Logistic Regression Regularization

# %% [markdown]
# In the first article, we demonstrated how polynomial features allow linear models to build nonlinear separating surfaces. Let's now show this visually.
#
# Let's see how regularization affects the quality of classification on a dataset on microchip testing from Andrew Ng's course on machine learning. We will use logistic regression with polynomial features and vary the regularization parameter $C$. First, we will see how regularization affects the separating border of the classifier and intuitively recognize under- and overfitting. Then, we will choose the regularization parameter to be numerically close to the optimal value via (`cross-validation`) and (`GridSearch`).

# %%
# we don't like warnings
# you can comment the following 2 lines if you'd like to
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import (GridSearchCV, StratifiedKFold,
                                    cross_val_score)
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# Let's load the data using `read_csv` from the `pandas` library. In this dataset on 118 microchips (objects), there are results for two tests of quality control (two numerical variables) and information whether the microchip went into production. Variables are already centered, meaning that the column values have had their own mean values subtracted. Thus, the "average" microchip corresponds to a zero value in the test results.

# %%
# loading data
data = pd.read_csv(
    "../../data/microchip_tests.txt", header=None, names=("test1", "test2", "released")
)
# getting some info about dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   test1     118 non-null    float64
#  1   test2     118 non-null    float64
#  2   released  118 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.9 KB

# %% [markdown]
# Let's inspect at the first and last 5 lines.

# %%
data.head(5)
# Out:
#       test1    test2  released
# 0  0.051267  0.69956         1
# 1 -0.092742  0.68494         1
# 2 -0.213710  0.69225         1
# 3 -0.375000  0.50219         1
# 4 -0.513250  0.46564         1

# %%
data.tail(5)
# Out:
#         test1     test2  released
# 113 -0.720620  0.538740         0
# 114 -0.593890  0.494880         0
# 115 -0.484450  0.999270         0
# 116 -0.006336  0.999270         0
# 117  0.632650 -0.030612         0

# %% [markdown]
# Now we should save the training set and the target class labels in separate NumPy arrays.

# %%
X = data.iloc[:, :2].values
y = data.iloc[:, 2].values

# %% [markdown]
# As an intermediate step, we can plot the data. Orange points correspond to defective chips, blue to normal ones.

# %%
plt.scatter(X[y == 1, 0], X[y == 1, 1], c="blue", label="Released")
plt.scatter(X[y == 0, 0], X[y == 0, 1], c="orange", label="Faulty")
plt.xlabel("Test 1")
plt.ylabel("Test 2")
plt.title("2 tests of microchips. Logit with C=1")
plt.legend();

# %% [markdown]
# Let's define a function to display the separating curve of the classifier.

# %%
def plot_boundary(clf, X, y, grid_step=0.01, poly_featurizer=None):
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(
        np.arange(x_min, x_max, grid_step), np.arange(y_min, y_max, grid_step)
    )

    # to every point from [x_min, m_max]x[y_min, y_max]
    # we put in correspondence its own color
    Z = clf.predict(poly_featurizer.transform(np.c_[xx.ravel(), yy.ravel()]))
    Z = Z.reshape(xx.shape)
    plt.contour(xx, yy, Z, cmap=plt.cm.Paired)

# %% [markdown]
# We define the following polynomial features of degree $d$ for two variables $x_1$ and $x_2$:
#
# $$\large \{x_1^d, x_1^{d-1}x_2, \ldots x_2^d\} =  \{x_1^ix_2^j\}_{i+j=d, i,j \in \mathbb{N}}$$
#
# For example, for $d=3$, this will be the following features:
#
# $$\large 1, x_1, x_2,  x_1^2, x_1x_2, x_2^2, x_1^3, x_1^2x_2, x_1x_2^2, x_2^3$$
#
# Drawing a Pythagorean Triangle would show how many of these features there will be for $d=4,5...$ and so on.
# The number of such features is exponentially large, and it can be costly to build polynomial features of large degree (e.g $d=10$) for 100 variables. More importantly, it's not needed.

# %% [markdown]
# We will use `sklearn`'s implementation of logistic regression. So, we create an object that will add polynomial features up to degree 7 to matrix $X$.

# %%
poly = PolynomialFeatures(degree=7)
X_poly = poly.fit_transform(X)

# %%
X_poly.shape
# Out:
# (118, 36)

# %% [markdown]
# Let's train logistic regression with regularization parameter $C = 10^{-2}$.

# %%
C = 1e-2
logit = LogisticRegression(C=C, random_state=17)
logit.fit(X_poly, y)

plot_boundary(logit, X, y, grid_step=0.01, poly_featurizer=poly)

plt.scatter(X[y == 1, 0], X[y == 1, 1], c="blue", label="Released")
plt.scatter(X[y == 0, 0], X[y == 0, 1], c="orange", label="Faulty")
plt.xlabel("Test 1")
plt.ylabel("Test 2")
plt.title("2 tests of microchips. Logit with C=%s" % C)
plt.legend()

print("Accuracy on training set:", round(logit.score(X_poly, y), 3))
# Out:
# Accuracy on training set: 0.627

# %% [markdown]
# We could now try increasing $C$ to 1. In doing this, we weaken regularization, and the solution can now have greater values (in absolute value) of model weights than previously. Now the accuracy of the classifier on the training set improves to 0.831.

# %%
C = 1
logit = LogisticRegression(C=C, random_state=17)
logit.fit(X_poly, y)

plot_boundary(logit, X, y, grid_step=0.005, poly_featurizer=poly)

plt.scatter(X[y == 1, 0], X[y == 1, 1], c="blue", label="Released")
plt.scatter(X[y == 0, 0], X[y == 0, 1], c="orange", label="Faulty")
plt.xlabel("Test 1")
plt.ylabel("Test 2")
plt.title("2 tests of microchips. Logit with C=%s" % C)
plt.legend()

print("Accuracy on training set:", round(logit.score(X_poly, y), 3))
# Out:
# Accuracy on training set: 0.831

# %% [markdown]
# Then, why don't we increase $C$ even more - up to 10,000? Now, regularization is clearly not strong enough, and we see overfitting. Note that, with $C$=1 and a "smooth" boundary, the share of correct answers on the training set is not much lower than here. But one can easily imagine how our second model will work much better on new data.

# %%
C = 1e4
logit = LogisticRegression(C=C, random_state=17)
logit.fit(X_poly, y)

plot_boundary(logit, X, y, grid_step=0.005, poly_featurizer=poly)

plt.scatter(X[y == 1, 0], X[y == 1, 1], c="blue", label="Released")
plt.scatter(X[y == 0, 0], X[y == 0, 1], c="orange", label="Faulty")
plt.xlabel("Test 1")
plt.ylabel("Test 2")
plt.title("2 tests of microchips. Logit with C=%s" % C)
plt.legend()

print("Accuracy on training set:", round(logit.score(X_poly, y), 3))
# Out:
# Accuracy on training set: 0.873

# %% [markdown]
# To discuss the results, let's rewrite the function that is optimized in logistic regression with the form:
#
# $$\large J(X,y,w) = \mathcal{L} + \frac{1}{C}||w||^2,$$
#
# where
#
# - $\mathcal{L}$ is the logistic loss function summed over the entire dataset
# - $C$ is the reverse regularization coefficient (the very same $C$ from `sklearn`'s implementation of `LogisticRegression`)

# %% [markdown]
# **Subtotals**:
# - the larger the parameter $C$, the more complex the relationships in the data that the model can recover (intuitively $C$ corresponds to the "complexity" of the model - model capacity)
# - if regularization is too strong i.e. the values of $C$ are small, the solution to the problem of minimizing the logistic loss function may be the one where many of the weights are too small or zeroed. The model is also not sufficiently "penalized" for errors (i.e. in the function $J$, the sum of the squares of the weights "outweighs", and the error $\mathcal{L}$ can be relatively large). In this case, the model will underfit as we saw in our first case.
# - on the contrary, if regularization is too weak i.e. the values of $C$ are large, a vector $w$ with high absolute value components can become the solution to the optimization problem. In this case, $\mathcal{L}$ has a greater contribution to the optimized functional $J$. Loosely speaking, the model is too "afraid" to be mistaken on the objects from the training set and will therefore overfit as we saw in the third case.
# - logistic regression will not "understand" (or "learn") what value of $C$ to choose as it does with the weights $w$. That is to say, it can not be determined by solving the optimization problem in logistic regression. We have seen a similar situation before -- a decision tree can not "learn" what depth limit to choose during the training process. Therefore, $C$ is the a model hyperparameter that is tuned on cross-validation; so is the max_depth in a tree.

# %% [markdown]
# **Regularization parameter tuning**

# %% [markdown]
# Using this example, let's identify the optimal value of the regularization parameter $C$. This can be done using `LogisticRegressionCV` - a grid search of parameters followed by cross-validation. This class is designed specifically for logistic regression (effective algorithms with well-known search parameters). For an arbitrary model, use `GridSearchCV`, `RandomizedSearchCV`, or special algorithms for hyperparameter optimization such as the one implemented in `hyperopt`.

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)

c_values = np.logspace(-2, 3, 500)

logit_searcher = LogisticRegressionCV(Cs=c_values, cv=skf, verbose=1, n_jobs=-1)
logit_searcher.fit(X_poly, y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# RUNNING THE L-BFGS-B CODE
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
#
#            * * *
#
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.58490D+01    |proj g|=  4.91966D+00
#
# At X0         0 variables are exactly at the bounds
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.51558D+01    |proj g|=  5.49607D+00
#
# At iterate    0    f=  6.51558D+01    |proj g|=  4.55487D+00
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.51558D+01    |proj g|=  4.90728D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
#    37      8     10      1     0     0   3.392D-06   6.521D+01
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#   F =   65.206879491538814
#            * * *
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      8     10      1     0     0   5.437D-04   6.458D+01
#   F =   64.578357340150930
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      8     11      1     0     0   3.449D-05   6.444D+01
#   F =   64.435234066067096
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      8     11      1     0     0   2.861D-05   6.450D+01
#   F =   64.501668624499459
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.45664D+01    |proj g|=  1.15650D-01
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.44205D+01    |proj g|=  9.27235D-02
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.44882D+01    |proj g|=  1.03046D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   5.459D-05   6.457D+01
#   F =   64.566085661098441
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.45538D+01    |proj g|=  1.15560D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   1.807D-04   6.442D+01
#   F =   64.420155735852376
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   1.782D-04   6.449D+01
#   F =   64.487893952515350
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   4.866D-05   6.455D+01
#   F =   64.553558074465712
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.44051D+01    |proj g|=  9.26650D-02
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.45410D+01    |proj g|=  1.15475D-01
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.44741D+01    |proj g|=  1.02952D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   4.486D-05   6.454D+01
#   F =   64.540769852142418
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   1.515D-04   6.440D+01
#   F =   64.404777891812628
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# At iterate    0    f=  6.45280D+01    |proj g|=  1.15388D-01
#    37      6      9      1     0     0   1.456D-04   6.447D+01
#   F =   64.473840410747087
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43894D+01    |proj g|=  9.26073D-02
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.44598D+01    |proj g|=  1.02877D-01
#
# At iterate    0    f=  6.51934D+01    |proj g|=  1.06559D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   4.459D-05   6.453D+01
#   F =   64.527716204039208
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.45147D+01    |proj g|=  1.15299D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   2.501D-04   6.519D+01
#   F =   65.193145864027088
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   1.270D-04   6.439D+01
#   F =   64.389095618569115
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   1.174D-04   6.446D+01
#   F =   64.459503217262181
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.51794D+01    |proj g|=  1.06448D-01
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43734D+01    |proj g|=  9.25477D-02
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# At iterate    0    f=  6.44452D+01    |proj g|=  1.02800D-01
#    37      6      8      1     0     0   4.651D-05   6.451D+01
#   F =   64.514392276584843
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.45011D+01    |proj g|=  1.15207D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   1.083D-04   6.437D+01
#   F =   64.373103959603526
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   2.177D-04   6.518D+01
#   F =   65.179138857690120
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   9.488D-05   6.444D+01
#   F =   64.444877542038483
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43571D+01    |proj g|=  9.24859D-02
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.51652D+01    |proj g|=  1.06392D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   4.919D-05   6.450D+01
#   F =   64.500793152787267
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.44872D+01    |proj g|=  1.15114D-01
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.44303D+01    |proj g|=  1.02720D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   9.546D-05   6.436D+01
#   F =   64.356797918691001
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   1.864D-04   6.516D+01
#   F =   65.164853931648622
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43405D+01    |proj g|=  9.24220D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
#    37      6      8      1     0     0   5.122D-05   6.449D+01
# Machine precision = 2.220D-16
#   F =   64.486913852328385
#  N =           37     M =           10
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.51506D+01    |proj g|=  1.06335D-01
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.44731D+01    |proj g|=  1.15018D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   7.823D-05   6.443D+01
#   F =   64.429958508096718
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   8.808D-05   6.434D+01
#   F =   64.340172461138977
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.44151D+01    |proj g|=  1.02637D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   1.600D-04   6.515D+01
#   F =   65.150286502314799
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   5.130D-05   6.447D+01
#   F =   64.472749331694558
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43236D+01    |proj g|=  9.23559D-02
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.51357D+01    |proj g|=  1.06276D-01
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.44586D+01    |proj g|=  1.14920D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   6.712D-05   6.441D+01
#   F =   64.414741192423705
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43995D+01    |proj g|=  1.02552D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      9      1     0     0   1.386D-04   6.514D+01
#   F =   65.135431944692257
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   8.553D-05   6.432D+01
#   F =   64.323222515083813
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.51206D+01    |proj g|=  1.06214D-01
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43063D+01    |proj g|=  9.22877D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   6.097D-05   6.440D+01
#   F =   64.399220626951802
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   8.686D-05   6.431D+01
#   F =   64.305942972846964
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# At iterate    0    f=  6.43837D+01    |proj g|=  1.02464D-01
#    37      6      9      1     0     0   1.223D-04   6.512D+01
#   F =   65.120285593195106
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.42887D+01    |proj g|=  9.22175D-02
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.51052D+01    |proj g|=  1.06149D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   9.093D-05   6.429D+01
#   F =   64.288328692351158
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   4.840D-05   6.446D+01
#   F =   64.458294484343511
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.42707D+01    |proj g|=  9.21455D-02
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.44439D+01    |proj g|=  1.14821D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   5.888D-05   6.438D+01
#   F =   64.383391799597533
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43676D+01    |proj g|=  1.02373D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   4.739D-05   6.444D+01
#   F =   64.443544140908330
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      7     11      1     0     0   5.831D-05   6.510D+01
#   F =   65.104842742442017
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.44288D+01    |proj g|=  1.14720D-01
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#
# At iterate    0    f=  6.50894D+01    |proj g|=  1.06070D-01
#    37      6      8      1     0     0   9.644D-05   6.427D+01
#   F =   64.270374498596127
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   5.968D-05   6.437D+01
#   F =   64.367249655360098
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
# RUNNING THE L-BFGS-B CODE
#  N =           37     M =           10
#
#            * * *
#
#
# At X0         0 variables are exactly at the bounds
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43511D+01    |proj g|=  1.02281D-01
#
# At iterate    0    f=  6.42525D+01    |proj g|=  9.20717D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   4.441D-05   6.443D+01
#   F =   64.428493069438758
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      7      9      1     0     0   1.018D-05   6.509D+01
#   F =   65.089098648311989
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Machine precision = 2.220D-16
#  N =           37     M =           10
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
#
# At X0         0 variables are exactly at the bounds
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.44135D+01    |proj g|=  1.14618D-01
#
# At iterate    0    f=  6.50734D+01    |proj g|=  1.06016D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      7      9      1     0     0   1.657D-05   6.425D+01
#   F =   64.252075185047090
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      7      9      1     0     0   8.570D-06   6.507D+01
#   F =   65.073048528704064
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.42338D+01    |proj g|=  9.19780D-02
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.50570D+01    |proj g|=  1.05941D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      7      9      1     0     0   1.857D-05   6.423D+01
#   F =   64.233425515787857
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      7      9      1     0     0   7.801D-06   6.506D+01
#   F =   65.056687564477016
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.42148D+01    |proj g|=  9.18996D-02
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.50404D+01    |proj g|=  1.05865D-01
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   6.208D-05   6.435D+01
#   F =   64.350789097480430
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   3.942D-05   6.441D+01
#   F =   64.413135975680603
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43344D+01    |proj g|=  1.02186D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      7      9      1     0     0   2.040D-05   6.421D+01
#   F =   64.214420226376149
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.41955D+01    |proj g|=  9.18195D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      7      9      1     0     0   7.742D-06   6.504D+01
#   F =   65.040010900553781
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43978D+01    |proj g|=  1.14513D-01
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.50234D+01    |proj g|=  1.05788D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   6.467D-05   6.433D+01
#   F =   64.334004988660894
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43173D+01    |proj g|=  1.02089D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      7      9      1     0     0   2.198D-05   6.420D+01
#   F =   64.195054026060689
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      7      9      1     0     0   7.703D-06   6.502D+01
#   F =   65.023013646910286
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   3.275D-05   6.440D+01
#   F =   64.397467503392789
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.41757D+01    |proj g|=  9.17379D-02
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.50061D+01    |proj g|=  1.05708D-01
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43818D+01    |proj g|=  1.14408D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      7      9      1     0     0   8.786D-06   6.501D+01
#   F =   65.005690879642245
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.49884D+01    |proj g|=  1.05627D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   2.518D-05   6.438D+01
#   F =   64.381482234702716
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      7      9      1     0     0   2.321D-05   6.418D+01
#   F =   64.175321599426212
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.43655D+01    |proj g|=  1.14301D-01
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.41556D+01    |proj g|=  9.16546D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      7      9      1     0     0   1.013D-05   6.499D+01
#   F =   64.988037642065436
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37      6      8      1     0     0   6.613D-05   6.432D+01
# ...
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     62     74      1     0     0   1.668D-04   2.877D+01
#   F =   28.768302737336388
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.87308D+01    |proj g|=  7.60404D-04
#
# At iterate   50    f=  2.87303D+01    |proj g|=  5.88265D-04
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     71     80      1     0     0   1.791D-04   2.873D+01
#   F =   28.730336144412828
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.86928D+01    |proj g|=  7.44470D-04
#
# At iterate   50    f=  2.86923D+01    |proj g|=  7.12076D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     61     70      1     0     0   1.189D-04   2.869D+01
#   F =   28.692325263983463
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.86547D+01    |proj g|=  8.03099D-04
#
# At iterate   50    f=  2.86543D+01    |proj g|=  2.60720D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     60     68      1     0     0   7.006D-04   2.865D+01
#   F =   28.654266918096184
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.86166D+01    |proj g|=  9.09438D-04
#
# At iterate   50    f=  2.86162D+01    |proj g|=  2.38589D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     54     64      1     0     0   2.193D-04   2.862D+01
#   F =   28.616166901697802
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.85785D+01    |proj g|=  7.10491D-04
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   50    f=  2.85780D+01    |proj g|=  1.57557D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     51     60      1     0     0   1.479D-04   2.858D+01
#   F =   28.578023809114079
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.85403D+01    |proj g|=  7.59569D-04
#
# At iterate   50    f=  2.85398D+01    |proj g|=  2.34844D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     60     70      1     0     0   1.696D-04   2.854D+01
#   F =   28.539837032490297
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.85021D+01    |proj g|=  7.44855D-04
#
# At iterate   50    f=  2.85016D+01    |proj g|=  5.21655D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     65     72      1     0     0   2.507D-04   2.850D+01
#   F =   28.501609307181567
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.84638D+01    |proj g|=  7.18357D-04
#
# At iterate   50    f=  2.84633D+01    |proj g|=  2.70384D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     51     58      1     0     0   3.068D-04   2.846D+01
#   F =   28.463344932621652
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.84255D+01    |proj g|=  7.24311D-04
#
# At iterate   50    f=  2.84250D+01    |proj g|=  2.38425D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     62     69      1     0     0   6.381D-04   2.843D+01
#   F =   28.425028691988537
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.83871D+01    |proj g|=  6.37808D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     48     60      1     0     0   2.398D-03   2.839D+01
#   F =   28.386680622138652
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.83487D+01    |proj g|=  2.39792D-03
#
# At iterate   50    f=  2.83483D+01    |proj g|=  1.20166D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     81     92      1     0     0   1.063D-04   2.835D+01
#   F =   28.348285381973376
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.83103D+01    |proj g|=  7.87735D-04
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   50    f=  2.83099D+01    |proj g|=  1.95179D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     74     86      1     0     0   6.902D-04   2.831D+01
#   F =   28.309860125410420
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.82718D+01    |proj g|=  9.30133D-04
#
# At iterate   50    f=  2.82714D+01    |proj g|=  2.71594D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     64     74      1     0     0   3.504D-04   2.827D+01
#   F =   28.271397406665372
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.82334D+01    |proj g|=  7.92349D-04
#
# At iterate   50    f=  2.82329D+01    |proj g|=  2.71084D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     80     88      1     0     0   1.356D-04   2.823D+01
#   F =   28.232895806072769
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.81948D+01    |proj g|=  7.37471D-04
#
# At iterate   50    f=  2.81944D+01    |proj g|=  3.87689D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     65     75      1     0     0   3.323D-04   2.819D+01
#   F =   28.194363593765175
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           37     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.81563D+01    |proj g|=  5.77798D-04
#
# At iterate   50    f=  2.81558D+01    |proj g|=  3.88894D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    37     83     92      1     0     0   1.040D-03   2.816D+01
#   F =   28.155798234005392
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   22.4s finished
# LogisticRegressionCV(Cs=array([1.00000000e-02, 1.02334021e-02, 1.04722519e-02, 1.07166765e-02,
#        1.09668060e-02, 1.12227736e-02, 1.14847155e-02, 1.17527712e-02,
#        1.20270833e-02, 1.23077980e-02, 1.25950646e-02, 1.28890361e-02,
#        1.31898690e-02, 1.34977233e-02, 1.38127630e-02, 1.41351558e-02,
#        1.44650734e-02, 1.48026913e-02, 1.51481892e-02, 1.55017512e-02,
#        1.58635653e-02, 1.62...
#        6.45088409e+02, 6.60144909e+02, 6.75552832e+02, 6.91320378e+02,
#        7.07455942e+02, 7.23968114e+02, 7.40865683e+02, 7.58157646e+02,
#        7.75853206e+02, 7.93961785e+02, 8.12493021e+02, 8.31456781e+02,
#        8.50863158e+02, 8.70722485e+02, 8.91045332e+02, 9.11842520e+02,
#        9.33125118e+02, 9.54904456e+02, 9.77192128e+02, 1.00000000e+03]),
#                      cv=StratifiedKFold(n_splits=5, random_state=17, shuffle=True),
#                      n_jobs=-1, verbose=1)

# %%
logit_searcher.C_
# Out:
# array([150.78450459])

# %% [markdown]
# To see how the quality of the model (percentage of correct responses on the training and validation sets) varies with the hyperparameter $C$, we can plot the graph.

# %%
plt.plot(c_values, np.mean(logit_searcher.scores_[1], axis=0))
plt.xlabel("C")
plt.ylabel("Mean CV-accuracy");

# %% [markdown]
# Finally, select the area with the "best" values of $C$.

# %%
plt.plot(c_values, np.mean(logit_searcher.scores_[1], axis=0))
plt.xlabel("C")
plt.ylabel("Mean CV-accuracy")
plt.xlim((0, 10));

# %% [markdown]
# Recall that these curves are called validation curves. Previously, we built them manually, but sklearn has special methods to construct these that we will use going forward.

# %% [markdown]
# ### Useful resources
# - Main course [site](https://mlcourse.ai), [course repo](https://github.com/Yorko/mlcourse.ai), and YouTube [channel](https://www.youtube.com/watch?v=QKTuw4PNOsU&list=PLVlY_7IJCMJeRfZ68eVfEcu-UcN9BbwiX)
# - Medium ["story"](https://medium.com/open-machine-learning-course/open-machine-learning-course-topic-4-linear-classification-and-regression-44a41b9b5220) based on this notebook
# - Course materials as a [Kaggle Dataset](https://www.kaggle.com/kashnitsky/mlcourse)
# - If you read Russian: an [article](https://habrahabr.ru/company/ods/blog/323890/) on Habrahabr with ~ the same material. And a [lecture](https://youtu.be/oTXGQ-_oqvI) on YouTube
# - A nice and concise overview of linear models is given in the book [“Deep Learning”](http://www.deeplearningbook.org) (I. Goodfellow, Y. Bengio, and A. Courville).
# - Linear models are covered practically in every ML book. We recommend “Pattern Recognition and Machine Learning” (C. Bishop) and “Machine Learning: A Probabilistic Perspective” (K. Murphy).
# - If you prefer a thorough overview of linear model from a statistician’s viewpoint, then look at “The elements of statistical learning” (T. Hastie, R. Tibshirani, and J. Friedman).
# - The book “Machine Learning in Action” (P. Harrington) will walk you through implementations of classic ML algorithms in pure Python.
# - [Scikit-learn](http://scikit-learn.org/stable/documentation.html) library. These guys work hard on writing really clear documentation.
# - Scipy 2017 [scikit-learn tutorial](https://github.com/amueller/scipy-2017-sklearn) by Alex Gramfort and Andreas Mueller.
# - One more [ML course](https://github.com/diefimov/MTH594_MachineLearning) with very good materials.
# - [Implementations](https://github.com/rushter/MLAlgorithms) of many ML algorithms. Search for linear regression and logistic regression.
